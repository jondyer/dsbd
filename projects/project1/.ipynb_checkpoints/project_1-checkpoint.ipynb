# %% [markdown]
# # Theme
# 1. Is college worth it?
# 2. More specifically, is CMU worth it for you?
#
# # Questions to ask
# ## Basic questions
# - Tableau a map of institutions
# - Accessibility to low-income students vs. graduation rates and earnings outcomes
#
# ## Time series
# - Change in tuition costs
# - Change in popular programs

# %% [markdown]
# ---
#
#
# Let's consider some comparisons of graduation rates based on the scorecard data...

# %%
from IPython.display import Image

# %%
Image('img/completion_race.png')

# %%
Image('img/completion_loans.png')

# %% [markdown]
# # EDA #
# Let's find out how low-income access and earnings outcomes look together.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('Most-Recent-Cohorts-All-Data-Elements.csv', na_values='PrivacySuppressed')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-43a29bc47bc4> in <module>()
# ----> 1 data = pd.read_csv('Most-Recent-Cohorts-All-Data-Elements.csv', na_values='PrivacySuppressed')
#       2 data.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Most-Recent-Cohorts-All-Data-Elements.csv' does not exist: b'Most-Recent-Cohorts-All-Data-Elements.csv'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Columns: 1977 entries, UNITID to OMENRUP_PARTTIME_POOLED_SUPP
# dtypes: float64(1944), int64(14), object(19)
# memory usage: 107.3+ MB

# %% [markdown]
# ## Tuition vs Earnings

# %%
# let's get tuition, mean/median earnings after 10 years, admittance rates, percentage of Pell grants,retention rate at 4-year colleges
sub_data = data[['UNITID',
                 'TUITIONFEE_IN', 
                 'TUITIONFEE_OUT', 
                 'MN_EARN_WNE_P10', 
                 'MD_EARN_WNE_P10', 
                 'ADM_RATE',
                 'PCTPELL',
                'RET_FT4','C150_4']].copy()
sub_data.head()
# Out:
#    UNITID  TUITIONFEE_IN  TUITIONFEE_OUT  ...  PCTPELL  RET_FT4  C150_4
# 0  100654         9857.0         18236.0  ...   0.7100   0.5879  0.2396
# 1  100663         8328.0         19032.0  ...   0.3532   0.8436  0.5292
# 2  100690         6900.0          6900.0  ...   0.7415   0.6667  0.1818
# 3  100706        10280.0         21480.0  ...   0.2765   0.8248  0.4862
# 4  100724        11068.0         19396.0  ...   0.7377   0.5923  0.2769
#
# [5 rows x 9 columns]

# %%
sub_data['MN_EARN_WNE_P10'] = pd.to_numeric(sub_data['MN_EARN_WNE_P10'])
sub_data['MD_EARN_WNE_P10'] = pd.to_numeric(sub_data['MD_EARN_WNE_P10'])
sub_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Data columns (total 9 columns):
# UNITID             7112 non-null int64
# TUITIONFEE_IN      4021 non-null float64
# TUITIONFEE_OUT     3793 non-null float64
# MN_EARN_WNE_P10    5175 non-null float64
# MD_EARN_WNE_P10    5175 non-null float64
# ADM_RATE           2037 non-null float64
# PCTPELL            6342 non-null float64
# RET_FT4            2174 non-null float64
# C150_4             2383 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 500.1 KB

# %%
# let's start with in-state tuition for now
plt.figure()
sub_data.plot.scatter(x='TUITIONFEE_IN', y='MN_EARN_WNE_P10', figsize=(15,15))

# %%
# interesting... now the median?
sub_data.plot.scatter(x='TUITIONFEE_IN', y='MD_EARN_WNE_P10', figsize=(12,12))

# %%
# let's mix in the admission rate of these schools
sub_data.plot.scatter(x='TUITIONFEE_IN', y='MN_EARN_WNE_P10', c='ADM_RATE', cmap='plasma', figsize=(12,10))

# %%
# interesting... let's look more at admission rates vs. earnings
sub_data.plot.scatter(x='ADM_RATE', y='MN_EARN_WNE_P10', figsize=(12,10))

# %%
# and now mix in tuition rate again
plt.figure()
sub_data.plot.scatter(x='ADM_RATE', y='MN_EARN_WNE_P10', c='TUITIONFEE_IN', cmap='plasma', figsize=(12,10))

# %%
# Is there a pattern between Percentage of Pell grant students and mean earnings?
plt.figure()
sub_data.plot.scatter(x='PCTPELL', y='MD_EARN_WNE_P10', figsize=(15,15))

# %%
plt.figure()
sub_data.plot.scatter(x='PCTPELL', y='RET_FT4', figsize=(15,15))

# %%
plt.figure()
sub_data.plot.scatter(x='PCTPELL', y='C150_4', figsize=(15,15))

# %% [markdown]
# # Data loading #
# We want all data (just the columns we care about) loaded together so that we can look at change over time... Let's do it.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

plt.style.use('seaborn')

# %%
cols_of_interest = ['UNITID',
                    'INSTNM',
                    'ADM_RATE',
                    'TUITIONFEE_IN',    # instate tuition
                    'TUITIONFEE_OUT',   # out of state tuition
                    'C150_4',    # completion rate within 150% of expected time
                    'MN_EARN_WNE_P6', 
                    'MD_EARN_WNE_P6', 
                    'PCTPELL',      # percent of students receiving pell grant (2008 on)
                    'RET_FT4',    # percent of students enrolled 1 yr after starting
                    'UGDS',    # not available in 2000-2001 file
                    'TUITFTE',    # net tuition revenue per student
                    'INEXPFTE',   # instructional expenditure per student
                    'AVGFACSAL',  # avg faculty salary per month
                    'PCTFLOAN',   # pct of students receiving federal loans
                    'CDR2',       # 2-yr default rate (2012 and prior)
                    'CDR3',       # 3-yr default rate (2012 on)
                    'DEBT_MDN',   # median loan debt accumulated
                    'PELL_DEBT_MDN',
                    'NOPELL_DEBT_MDN',
                    'PELL_EVER',  # students who received pell grant ever
                    'LOAN_EVER',  # students who received loan ever
                    'FAMINC',     # avg family income in 2015 dollars (earnings cohort)
                    'MD_FAMINC',  # median family income (earnings cohort)
                    'DEBT_MDN_SUPP',  # median debt suppressed for n < 30
                    'GRAD_DEBT_MDN_SUPP', # same, but for completers
                    'CONTROL', # 1: Public, 2: Private nonprof, 3: Priv for-prof
                    ]

# now set up the data types of these columns -- all but the name will be floats
col_types = {a: np.dtype('float64') for a in cols_of_interest[2:-1]}
col_types['UNITID'] = np.dtype('int64')
col_types['CONTROL'] = np.dtype('int64')

# %%
# now test on one file
data = pd.read_csv('data/MERGED2008_09_PP.csv', na_values='PrivacySuppressed', 
                   usecols=cols_of_interest, dtype=col_types)
data.head()
# Out:
#    UNITID  ... GRAD_DEBT_MDN_SUPP
# 0  100654  ...            19126.0
# 1  100663  ...            13000.0
# 2  100690  ...            14090.0
# 3  100706  ...            14500.0
# 4  100724  ...            21942.0
#
# [5 rows x 27 columns]

# %%
# get info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2402 entries, 0 to 2401
# Data columns (total 27 columns):
# UNITID                2402 non-null int64
# INSTNM                2402 non-null object
# CONTROL               2402 non-null int64
# ADM_RATE              1012 non-null float64
# UGDS                  2282 non-null float64
# TUITIONFEE_IN         1675 non-null float64
# TUITIONFEE_OUT        1675 non-null float64
# TUITFTE               2392 non-null float64
# INEXPFTE              2392 non-null float64
# AVGFACSAL             1822 non-null float64
# PCTPELL               2274 non-null float64
# C150_4                997 non-null float64
# RET_FT4               986 non-null float64
# PCTFLOAN              0 non-null float64
# CDR2                  2355 non-null float64
# CDR3                  0 non-null float64
# DEBT_MDN              2013 non-null float64
# PELL_DEBT_MDN         1836 non-null float64
# NOPELL_DEBT_MDN       1836 non-null float64
# LOAN_EVER             1835 non-null float64
# PELL_EVER             1944 non-null float64
# FAMINC                2298 non-null float64
# MD_FAMINC             2298 non-null float64
# MN_EARN_WNE_P10       0 non-null float64
# MD_EARN_WNE_P10       0 non-null float64
# DEBT_MDN_SUPP         1982 non-null float64
# GRAD_DEBT_MDN_SUPP    1772 non-null float64
# dtypes: float64(24), int64(2), object(1)
# memory usage: 506.8+ KB

# %%
# also want the year in here as a column... 
# we'll use the second of the two for any school year
data['Year'] = pd.Period('2009', freq='Y')
data.head(1)
# Out:
#    UNITID                    INSTNM  ...  GRAD_DEBT_MDN_SUPP  Year
# 0  100654  Alabama A & M University  ...             19126.0  2009
#
# [1 rows x 28 columns]

# %% [markdown]
# Now let's wrap it all up into a reusable function!

# %%
def read_college_files(year, cols, col_types):
  '''
  This function reads a single csv file from the College Scorecard dataset,
  adds a 'Year' column, and returns the data as a Dataframe.

  Assumes the files are in a directory called 'data'.
  '''
  second_year_abbrev = str(year+1)[2:]
  fname = f"data/MERGED{year}_{second_year_abbrev}_PP.csv"
  frame = pd.read_csv(fname, na_values=['PrivacySuppressed','PrivacySuppr'], 
                   usecols=cols, dtype=col_types)
  frame['Year'] = pd.Period(str(year+1), freq='Y')

  return frame

# %%
# let's test it on all the files, concatenating so we can have tidy time-series data
data = pd.concat(read_college_files(year, cols_of_interest, col_types) for year in range(1996,2018))
data.head()
# Out:
#    UNITID                                  INSTNM  ...  GRAD_DEBT_MDN_SUPP  Year
# 0  100636      Community College of the Air Force  ...                 NaN  1997
# 1  100654                Alabama A & M University  ...                 NaN  1997
# 2  100663     University of Alabama at Birmingham  ...                 NaN  1997
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE  ...                 NaN  1997
# 4  100690                      Amridge University  ...                 NaN  1997
#
# [5 rows x 28 columns]

# %%
# !ls data

# %%
data[data['INSTNM'].str.contains('Carnegie Mellon')].head(20)
# Out:
#       UNITID                      INSTNM  ...  GRAD_DEBT_MDN_SUPP  Year
# 4085  211440  Carnegie Mellon University  ...                 NaN  1997
# 3904  211440  Carnegie Mellon University  ...                 NaN  1998
# 3785  211440  Carnegie Mellon University  ...                 NaN  1999
# 3745  211440  Carnegie Mellon University  ...                 NaN  2000
# 3677  211440  Carnegie Mellon University  ...                 NaN  2001
# 3673  211440  Carnegie Mellon University  ...                 NaN  2002
# 3517  211440  Carnegie Mellon University  ...             17125.0  2006
# 3009  211440  Carnegie Mellon University  ...             26462.0  2017
# 2967  211440  Carnegie Mellon University  ...                 NaN  2018
#
# [9 rows x 28 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77970 entries, 0 to 7111
# Data columns (total 28 columns):
# UNITID                77970 non-null int64
# INSTNM                77970 non-null object
# CONTROL               77970 non-null int64
# ADM_RATE              19379 non-null float64
# UGDS                  69465 non-null float64
# TUITIONFEE_IN         35692 non-null float64
# TUITIONFEE_OUT        35246 non-null float64
# TUITFTE               62693 non-null float64
# INEXPFTE              62694 non-null float64
# AVGFACSAL             49477 non-null float64
# PCTPELL               25697 non-null float64
# C150_4                25085 non-null float64
# RET_FT4               14464 non-null float64
# PCTFLOAN              23422 non-null float64
# CDR2                  56280 non-null float64
# CDR3                  20390 non-null float64
# DEBT_MDN              52391 non-null float64
# PELL_DEBT_MDN         46479 non-null float64
# NOPELL_DEBT_MDN       46479 non-null float64
# LOAN_EVER             46981 non-null float64
# PELL_EVER             49821 non-null float64
# FAMINC                61000 non-null float64
# MD_FAMINC             61000 non-null float64
# MN_EARN_WNE_P10       9159 non-null float64
# MD_EARN_WNE_P10       9159 non-null float64
# DEBT_MDN_SUPP         51305 non-null float64
# GRAD_DEBT_MDN_SUPP    43057 non-null float64
# Year                  77970 non-null object
# dtypes: float64(24), int64(2), object(2)
# memory usage: 17.3+ MB

# %%
# we want Year at the front (after UNITID) so let's reindex
new_col_names = cols_of_interest[:1] + ['Year'] + cols_of_interest[1:]
data = data.reindex(columns=new_col_names)
data.head(0)
# Out:
# Empty DataFrame
# Columns: [UNITID, Year, INSTNM, ADM_RATE, TUITIONFEE_IN, TUITIONFEE_OUT, C150_4, MN_EARN_WNE_P10, MD_EARN_WNE_P10, PCTPELL, RET_FT4, UGDS, TUITFTE, INEXPFTE, AVGFACSAL, PCTFLOAN, CDR2, CDR3, DEBT_MDN, PELL_DEBT_MDN, NOPELL_DEBT_MDN, PELL_EVER, LOAN_EVER, FAMINC, MD_FAMINC, DEBT_MDN_SUPP, GRAD_DEBT_MDN_SUPP, CONTROL]
# Index: []

# %%
# this cell just writes out the data we've selected and cleaned to a single csv
def write_data(data, filename):
  data.to_csv(filename, index=False)

# %%
write_data(data, "time_series_cleaned_data.csv")

# %% [markdown]
# # Time series analysis
# Now let's investigate how costs have changed over time, starting with CMU.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)

# %%
# set up a font dictionary for nice graphs
font = {'family' : 'normal',
        'size'   : 18}
plt.style.use('seaborn')  # also a nice style

# %%
df = pd.read_csv('data/time_series_cleaned_data.csv', parse_dates=['Year'],)
df.head()
# Out:
#         Year  UNITID  ... GRAD_DEBT_MDN_SUPP  CONTROL
# 0 1997-01-01  100636  ...                NaN      1.0
# 1 1997-01-01  100654  ...                NaN      1.0
# 2 1997-01-01  100663  ...                NaN      1.0
# 3 1997-01-01  100672  ...                NaN      1.0
# 4 1997-01-01  100690  ...                NaN      2.0
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113410 entries, 0 to 113409
# Data columns (total 28 columns):
# Year                  113410 non-null datetime64[ns]
# UNITID                113410 non-null int64
# INSTNM                113410 non-null object
# ADM_RATE              33546 non-null float64
# TUITIONFEE_IN         56384 non-null float64
# TUITIONFEE_OUT        56385 non-null float64
# C150_4                37090 non-null float64
# MN_EARN_WNE_P10       24647 non-null float64
# MD_EARN_WNE_P10       24647 non-null float64
# PCTPELL               37343 non-null float64
# RET_FT4               23930 non-null float64
# UGDS                  101804 non-null float64
# TUITFTE               97705 non-null float64
# INEXPFTE              97700 non-null float64
# AVGFACSAL             71021 non-null float64
# PCTFLOAN              32823 non-null float64
# CDR2                  94358 non-null float64
# CDR3                  23571 non-null float64
# DEBT_MDN              86597 non-null float64
# PELL_DEBT_MDN         76455 non-null float64
# NOPELL_DEBT_MDN       76455 non-null float64
# PELL_EVER             82254 non-null float64
# LOAN_EVER             78219 non-null float64
# FAMINC                101927 non-null float64
# MD_FAMINC             101927 non-null float64
# DEBT_MDN_SUPP         84867 non-null float64
# GRAD_DEBT_MDN_SUPP    73304 non-null float64
# CONTROL               113409 non-null float64
# dtypes: datetime64[ns](1), float64(25), int64(1), object(1)
# memory usage: 24.2+ MB

# %% [markdown]
# We're looking for general trends in schools, so let's filter those that are too small.

# %%
MIN_SIZE = (df['UGDS'] > 5000)  # this mask value can be changed if needed
big_schools = df[MIN_SIZE]
big_schools.head()
# Out:
#          Year  UNITID  ... GRAD_DEBT_MDN_SUPP  CONTROL
# 0  1997-01-01  100636  ...                NaN      1.0
# 2  1997-01-01  100663  ...                NaN      1.0
# 7  1997-01-01  100751  ...                NaN      1.0
# 11 1997-01-01  100858  ...                NaN      1.0
# 28 1997-01-01  101240  ...                NaN      1.0
#
# [5 rows x 28 columns]

# %%
# let's try selecting just CMU
mask = (df['INSTNM'].str.contains('Carnegie Mellon'))
df[mask].head(10)
# Out:
#             Year  UNITID  ... GRAD_DEBT_MDN_SUPP  CONTROL
# 4085  1997-01-01  211440  ...                NaN      2.0
# 10698 1998-01-01  211440  ...                NaN      2.0
# 17278 1999-01-01  211440  ...                NaN      2.0
# 23718 2000-01-01  211440  ...                NaN      2.0
# 30116 2001-01-01  211440  ...                NaN      2.0
# 36590 2002-01-01  211440  ...                NaN      2.0
# 43162 2003-01-01  211440  ...            14500.0      2.0
# 49476 2004-01-01  211440  ...            17125.0      2.0
# 55563 2005-01-01  211440  ...            17125.0      2.0
# 61037 2006-01-01  211440  ...            17125.0      2.0
#
# [10 rows x 28 columns]

# %%
cmu = df[mask].copy()
cmu.set_index('Year', inplace=True)
cmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 1997-01-01 to 2016-01-01
# Data columns (total 27 columns):
# UNITID                20 non-null int64
# INSTNM                20 non-null object
# ADM_RATE              15 non-null float64
# TUITIONFEE_IN         16 non-null float64
# TUITIONFEE_OUT        16 non-null float64
# C150_4                19 non-null float64
# MN_EARN_WNE_P10       6 non-null float64
# MD_EARN_WNE_P10       6 non-null float64
# PCTPELL               8 non-null float64
# RET_FT4               12 non-null float64
# UGDS                  19 non-null float64
# TUITFTE               18 non-null float64
# INEXPFTE              18 non-null float64
# AVGFACSAL             19 non-null float64
# PCTFLOAN              7 non-null float64
# CDR2                  17 non-null float64
# CDR3                  5 non-null float64
# DEBT_MDN              19 non-null float64
# PELL_DEBT_MDN         19 non-null float64
# NOPELL_DEBT_MDN       19 non-null float64
# PELL_EVER             19 non-null float64
# LOAN_EVER             19 non-null float64
# FAMINC                19 non-null float64
# MD_FAMINC             19 non-null float64
# DEBT_MDN_SUPP         19 non-null float64
# GRAD_DEBT_MDN_SUPP    14 non-null float64
# CONTROL               20 non-null float64
# dtypes: float64(25), int64(1), object(1)
# memory usage: 4.4+ KB

# %% [markdown]
# Let's look at tuition changes first.

# %%
fig = plt.figure(figsize=(9,9))
ax = cmu.plot(y='TUITIONFEE_IN', figsize=(9,9))
ax.set(title='CMU tuition change over time', ylabel='Tuition cost ($)')
ax.set_xlim(pd.Timestamp('2001-01-01'))   # start where the data starts
plt.show()

# %%
# Looks pretty consistent! What if we compared it with just an average 3% inflation every year.
inflation = np.ones(22) +0.03
inflation[:4] = np.nan
inflation[4] = 25000   # start with $25,000
inflation = np.nancumprod(inflation)
inflation
# Out:
# array([1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        2.50000000e+04, 2.57500000e+04, 2.65225000e+04, 2.73181750e+04,
#        2.81377202e+04, 2.89818519e+04, 2.98513074e+04, 3.07468466e+04,
#        3.16692520e+04, 3.26193296e+04, 3.35979095e+04, 3.46058468e+04,
#        3.56440222e+04, 3.67133428e+04, 3.78147431e+04, 3.89491854e+04,
#        4.01176610e+04, 4.13211908e+04])

# %%
cmu['INFLATE'] = inflation
cmu.head()
# Out:
#             UNITID                      INSTNM  ...  CONTROL  INFLATE
# Year                                            ...
# 1997-01-01  211440  Carnegie Mellon University  ...      2.0      1.0
# 1998-01-01  211440  Carnegie Mellon University  ...      2.0      1.0
# 1999-01-01  211440  Carnegie Mellon University  ...      2.0      1.0
# 2000-01-01  211440  Carnegie Mellon University  ...      2.0      1.0
# 2001-01-01  211440  Carnegie Mellon University  ...      2.0  25000.0
#
# [5 rows x 28 columns]

# %%
ax = cmu.plot(y=['TUITIONFEE_IN', 'INFLATE'], figsize=(9,9),)
ax.set(title='CMU tuition change over time', ylabel='Cost ($)')
ax.set_xlim(pd.Timestamp('2001-01-01'))
plt.show()

# %% [markdown]
# While we're at it, let's see how CMU has changed with relation to some other variables.

# %%
cmu2 = cmu.reset_index()
cmu2.count()
# Out:
# Year                  20
# UNITID                20
# INSTNM                20
# ADM_RATE              15
# TUITIONFEE_IN         16
# TUITIONFEE_OUT        16
# C150_4                19
# MN_EARN_WNE_P10        6
# MD_EARN_WNE_P10        6
# PCTPELL                8
# RET_FT4               12
# UGDS                  19
# TUITFTE               18
# INEXPFTE              18
# AVGFACSAL             19
# PCTFLOAN               7
# CDR2                  17
# CDR3                   5
# DEBT_MDN              19
# PELL_DEBT_MDN         19
# NOPELL_DEBT_MDN       19
# PELL_EVER             19
# LOAN_EVER             19
# FAMINC                19
# MD_FAMINC             19
# DEBT_MDN_SUPP         19
# GRAD_DEBT_MDN_SUPP    14
# CONTROL               20
# dtype: int64

# %%
# pairplot lets us quickly look at many trends at once
pp = sns.pairplot(
    cmu2,
    vars=['Year',
          'ADM_RATE',
          'C150_4',
          'MD_EARN_WNE_P10',
          'UGDS',
          'AVGFACSAL',
          'CDR2',
          'DEBT_MDN',
          'PELL_DEBT_MDN',
          'PELL_EVER',
          'MD_FAMINC'],
    height=3)

for ax in pp.axes.flat:
  ax.tick_params(axis='x', labelbottom=True)

plt.subplots_adjust(hspace=0.3)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Well, even as tuition has gone up, it looks like so too have completion rates, debt, faculty salary, and earnings. At the same time default rates and admission rates have steadily decreased.
#
# Let's zoom in on a few of these.

# %%
sns.set(style="white")
ax = sns.relplot(x='Year', y='TUITIONFEE_IN', hue='DEBT_MDN_SUPP', size='DEBT_MDN_SUPP', sizes=(40,400), data=cmu2, alpha=0.5, palette='plasma', height=6)

# %% [markdown]
# ## CMU vs. other schools
# Clearly tuition has gone up faster than plain old inflation.
# How does this compare to other schools?

# %%
big_schools.count()
# Out:
# Year                  14490
# UNITID                14490
# INSTNM                14490
# ADM_RATE               6496
# TUITIONFEE_IN         11970
# TUITIONFEE_OUT        11970
# C150_4                 8117
# MN_EARN_WNE_P10        4954
# MD_EARN_WNE_P10        4954
# PCTPELL                6979
# RET_FT4                5671
# UGDS                  14490
# TUITFTE               13252
# INEXPFTE              13252
# AVGFACSAL             14409
# PCTFLOAN               6169
# CDR2                  11568
# CDR3                   4475
# DEBT_MDN              13624
# PELL_DEBT_MDN         13460
# NOPELL_DEBT_MDN       13460
# PELL_EVER             13514
# LOAN_EVER             13619
# FAMINC                13844
# MD_FAMINC             13844
# DEBT_MDN_SUPP         13607
# GRAD_DEBT_MDN_SUPP    11758
# CONTROL               14490
# dtype: int64

# %%
# for reproducibility
np.random.seed(95885)

# this is a very large data set, so let's sample some of them for plotting
gr = big_schools.groupby(by='UNITID')

# now create sample group of proper size
a = np.arange(gr.ngroups)   # get num groups (institution)
np.random.shuffle(a)        # randomize selection
selection = a[:500]         # just get some of them


# apply the filter to get new groupby - include CMU!
big_schools_sample = pd.concat([big_schools[gr.ngroup().isin(selection)], gr.get_group(211440)])
gr = big_schools_sample.groupby(by='UNITID')

# some schools are missing most of their data, so let's filter
data_filter = gr.count()['TUITIONFEE_IN'] > 15

# %%
# now for the tricky part
ax = plt.axes()

# plot each group if it falls in our sample selection or if it's CMU
for key, gp in gr:
  gp = gp.reset_index()
  if key==211440:   # this is CMU's id
    gp.plot(x='Year', y='TUITIONFEE_IN', c='teal', ax=ax, legend=False, figsize=(12,12))
  elif data_filter[key]:
    gp.plot(x='Year', y='TUITIONFEE_IN', alpha=0.2, c='darkorchid', ax=ax, legend=False, figsize=(12,12))

ax.set_xlim(pd.Timestamp('2000-01-01'), pd.Timestamp('2020-01-01'))
ax.set_title('Tuition change over time', fontdict=font, pad=5)
ax.set_ylabel('Tuition cost', fontdict=font, labelpad=10)
ax.set_xlabel('Year', fontdict=font, labelpad=10)
plt.show()

# %% [markdown]
# Interesting. Looks like some schools have stayed extremely consistent while CMU and some others have increased steadily. Now ultimately we want to look at how this compares to earnings outcomes, balanced against completion rates and admissions. So let's remove those schools that don't have the data we need.

# %%
# let's look at pricier, more selective schools with the data we want
gr = big_schools.groupby(by='UNITID')
data_filter = gr.count()[['TUITIONFEE_IN', 'C150_4', 'ADM_RATE', 'DEBT_MDN_SUPP']] > 13
data_filter.loc[211440, 'TUITIONFEE_IN']
# Out:
# True

# %%
# one year snapshot
big_pricey_schools = pd.concat([df for key, df in gr if any(data_filter.loc[key])])
big_pricey_schools.head()
# Out:
#             Year  UNITID  ... GRAD_DEBT_MDN_SUPP  CONTROL
# 2     1997-01-01  100663  ...                NaN      1.0
# 6796  1998-01-01  100663  ...            10500.0      1.0
# 13494 1999-01-01  100663  ...            10500.0      1.0
# 19974 2000-01-01  100663  ...            11300.0      1.0
# 32918 2002-01-01  100663  ...             4142.0      1.0
#
# [5 rows x 28 columns]

# %%
big_pricey_schools.groupby(by='Year').plot()
